# %% [markdown]
# # nbeats seq2seq 'Yearly' 적합 모델 예제

# %% [markdown]
# ####  밑의 소스코드를 활용한 seq2seq yearly 모델 구현예제
# - 다른 계절성 패턴과 lookback, loss 함수등의 여러 앙상블은 구현하지 않은 단편 모델
# - 데이터 구현 : https://github.com/ServiceNow/N-BEATS/tree/master
# - 모델 아키텍쳐 : https://github.com/philipperemy/n-beats

# %% [markdown]
# ---

# %%
from nbeats_keras.model import NBeatsNet as NBeatsKeras
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
#from nbeats_pytorch.model import NBeatsNet as NBeatsPytorch
from keras.optimizers import RMSprop, Adam

import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import time

# %% [markdown]
# ## m4data

# %%
import logging
import os
import pathlib
import sys
from urllib import request

def download(url: str, file_path: str) -> None:
    """
    Download a file to the given path.

    :param url: URL to download
    :param file_path: Where to download the content.
    """

    def progress(count, block_size, total_size):
        progress_pct = float(count * block_size) / float(total_size) * 100.0
        sys.stdout.write('\rDownloading {} to {} {:.1f}%'.format(url, file_path, progress_pct))
        sys.stdout.flush()

    if not os.path.isfile(file_path):
        opener = request.build_opener()
        opener.addheaders = [('User-agent', 'Mozilla/5.0')]
        request.install_opener(opener)
        pathlib.Path(os.path.dirname(file_path)).mkdir(parents=True, exist_ok=True)
        f, _ = request.urlretrieve(url, file_path, progress)
        sys.stdout.write('\n')
        sys.stdout.flush()
        file_info = os.stat(f)
        logging.info(f'Successfully downloaded {os.path.basename(file_path)} {file_info.st_size} bytes.')
    else:
        file_info = os.stat(file_path)
        logging.info(f'File already exists: {file_path} {file_info.st_size} bytes.')


def url_file_name(url: str) -> str:
    """
    Extract file name from url.

    :param url: URL to extract file name from.
    :return: File name.
    """
    return url.split('/')[-1] if len(url) > 0 else ''
"""
M4 Dataset
"""
import logging
import os
from collections import OrderedDict
from dataclasses import dataclass
from glob import glob

import numpy as np
import pandas as pd
#import patoolib
from tqdm import tqdm

#from common.http_utils import download, url_file_name
#from common.settings import DATASETS_PATH


STORAGE=os.getenv('STORAGE')
DATASETS_PATH=os.path.join(STORAGE, 'datasets')
EXPERIMENTS_PATH=os.path.join(STORAGE, 'experiments')
TESTS_STORAGE_PATH=os.path.join(STORAGE, 'test')
FREQUENCIES = ['Hourly', 'Daily', 'Weekly', 'Monthly', 'Quarterly', 'Yearly']
URL_TEMPLATE = 'https://github.com/Mcompetitions/M4-methods/raw/master/Dataset/{}/{}-{}.csv'

TRAINING_DATASET_URLS = [URL_TEMPLATE.format("Train", freq, "train") for freq in FREQUENCIES]
TEST_DATASET_URLS = [URL_TEMPLATE.format("Test", freq, "test") for freq in FREQUENCIES]
INFO_URL = 'https://github.com/Mcompetitions/M4-methods/raw/master/Dataset/M4-info.csv'
NAIVE2_FORECAST_URL = 'https://github.com/M4Competition/M4-methods/raw/master/Point%20Forecasts/submission-Naive2.rar'

DATASET_PATH = os.path.join(DATASETS_PATH, 'm4')

TRAINING_DATASET_FILE_PATHS = [os.path.join(DATASET_PATH, url_file_name(url)) for url in TRAINING_DATASET_URLS]
TEST_DATASET_FILE_PATHS = [os.path.join(DATASET_PATH, url_file_name(url)) for url in TEST_DATASET_URLS]
INFO_FILE_PATH = os.path.join(DATASET_PATH, url_file_name(INFO_URL))
NAIVE2_FORECAST_FILE_PATH = os.path.join(DATASET_PATH, 'submission-Naive2.csv')


TRAINING_DATASET_CACHE_FILE_PATH = os.path.join(DATASET_PATH, 'training.npz')
TEST_DATASET_CACHE_FILE_PATH = os.path.join(DATASET_PATH, 'test.npz')


@dataclass()
class M4Dataset:
    ids: np.ndarray
    groups: np.ndarray
    frequencies: np.ndarray
    horizons: np.ndarray
    values: np.ndarray

    @staticmethod
    def load(training: bool = True) -> 'M4Dataset':
        """
        Load cached dataset.

        :param training: Load training part if training is True, test part otherwise.
        """
        m4_info = pd.read_csv(INFO_FILE_PATH)
        return M4Dataset(ids=m4_info.M4id.values,
                         groups=m4_info.SP.values,
                         frequencies=m4_info.Frequency.values,
                         horizons=m4_info.Horizon.values,
                         values=np.load(
                             TRAINING_DATASET_CACHE_FILE_PATH if training else TEST_DATASET_CACHE_FILE_PATH,
                             allow_pickle=True))

    @staticmethod
    def download() -> None:
        """
        Download M4 dataset if doesn't exist.
        """
        if os.path.isdir(DATASET_PATH):
            logging.info(f'skip: {DATASET_PATH} directory already exists.')
            return

        download(INFO_URL, INFO_FILE_PATH)
        m4_ids = pd.read_csv(INFO_FILE_PATH).M4id.values

        def build_cache(files: str, cache_path: str) -> None:
            timeseries_dict = OrderedDict(list(zip(m4_ids, [[]] * len(m4_ids))))
            logging.info(f'Caching {files}')
            for train_csv in tqdm(glob(os.path.join(DATASET_PATH, files))):
                dataset = pd.read_csv(train_csv)
                dataset.set_index(dataset.columns[0], inplace=True)
                for m4id, row in dataset.iterrows():
                    values = row.values
                    timeseries_dict[m4id] = values[~np.isnan(values)]
            np.array(list(timeseries_dict.values())).dump(cache_path)

        for url, path in zip(TRAINING_DATASET_URLS, TRAINING_DATASET_FILE_PATHS):
            download(url, path)
        build_cache('*-train.csv', TRAINING_DATASET_CACHE_FILE_PATH)

        for url, path in zip(TEST_DATASET_URLS, TEST_DATASET_FILE_PATHS):
            download(url, path)
        build_cache('*-test.csv', TEST_DATASET_CACHE_FILE_PATH)

        naive2_archive = os.path.join(DATASET_PATH, url_file_name(NAIVE2_FORECAST_URL))
        download(NAIVE2_FORECAST_URL, naive2_archive)
        patoolib.extract_archive(naive2_archive, outdir=DATASET_PATH)


@dataclass()
class M4Meta:
    seasonal_patterns = ['Yearly', 'Quarterly', 'Monthly', 'Weekly', 'Daily', 'Hourly']
    horizons = [6, 8, 18, 13, 14, 48]
    frequencies = [1, 4, 12, 1, 1, 24]
    horizons_map = {
        'Yearly': 6,
        'Quarterly': 8,
        'Monthly': 18,
        'Weekly': 13,
        'Daily': 14,
        'Hourly': 48
    }
    frequency_map = {
        'Yearly': 1,
        'Quarterly': 4,
        'Monthly': 12,
        'Weekly': 1,
        'Daily': 1,
        'Hourly': 24
    }

def load_m4_info() -> pd.DataFrame:
    """
    Load M4Info file.

    :return: Pandas DataFrame of M4Info.
    """
    return pd.read_csv(INFO_FILE_PATH)

# %%
train = M4Dataset.load(training=True)
test = M4Dataset.load(training=False)

# %% [markdown]
# ---

# %% [markdown]
# ## data 전처리

# %%
def group_values(values: np.ndarray, groups: np.ndarray, group_name: str) -> np.ndarray:
    """
    Filter values array by group indices and clean it from NaNs.

    :param values: Values to filter.
    :param groups: Timeseries groups.
    :param group_name: Group name to filter by.
    :return: Filtered and cleaned timeseries.
    """
    return [v[~np.isnan(v)] for v in values[groups == group_name]]

# %%
M4Meta.seasonal_patterns
# Out:
# ['Yearly', 'Quarterly', 'Monthly', 'Weekly', 'Daily', 'Hourly']

# %%
# 계절성분별로 m4데이터 리스트로 분할
group_train= [group_values(train.values, train.groups, M4Meta.seasonal_patterns[i]) for i in range(len(M4Meta.seasonal_patterns))]
group_test= [group_values(test.values, test.groups, M4Meta.seasonal_patterns[i]) for i in range(len(M4Meta.seasonal_patterns))]

# %%
"""
Timeseries sampler
"""
import numpy as np

#import gin

#@gin.configurable
class TimeseriesSampler:
    def __init__(self,
                 timeseries: np.ndarray,
                 insample_size: int,
                 outsample_size: int,
                 window_sampling_limit: int,
                 batch_size: int = 1024):
        """
        Timeseries sampler.

        :param timeseries: Timeseries data to sample from. Shape: timeseries, timesteps
        :param insample_size: Insample window size. If timeseries is shorter then it will be 0-padded and masked.
        :param outsample_size: Outsample window size. If timeseries is shorter then it will be 0-padded and masked.
        :param window_sampling_limit: Size of history the sampler should use.
        :param batch_size: Number of sampled windows.
        """
        self.timeseries = [ts for ts in timeseries]
        self.window_sampling_limit = window_sampling_limit
        self.batch_size = batch_size
        self.insample_size = insample_size
        self.outsample_size = outsample_size

    def __iter__(self):
        """
        Batches of sampled windows.

        :return: Batches of:
         Insample: "batch size, insample size"
         Insample mask: "batch size, insample size"
         Outsample: "batch size, outsample size"
         Outsample mask: "batch size, outsample size"
        """
        while True:
            insample = np.zeros((self.batch_size, self.insample_size))
            insample_mask = np.zeros((self.batch_size, self.insample_size))
            outsample = np.zeros((self.batch_size, self.outsample_size))
            outsample_mask = np.zeros((self.batch_size, self.outsample_size))
            sampled_ts_indices = np.random.randint(len(self.timeseries), size=self.batch_size)
            for i, sampled_index in enumerate(sampled_ts_indices):
                sampled_timeseries = self.timeseries[sampled_index]
                cut_point = np.random.randint(low=max(1, len(sampled_timeseries) - self.window_sampling_limit),
                                              high=len(sampled_timeseries),
                                              size=1)[0]

                insample_window = sampled_timeseries[max(0, cut_point - self.insample_size):cut_point]
                insample[i, -len(insample_window):] = insample_window
                insample_mask[i, -len(insample_window):] = 1.0
                outsample_window = sampled_timeseries[
                                   cut_point:min(len(sampled_timeseries), cut_point + self.outsample_size)]
                outsample[i, :len(outsample_window)] = outsample_window
                outsample_mask[i, :len(outsample_window)] = 1.0
            yield insample, insample_mask, outsample, outsample_mask

    def last_insample_window(self):
        """
        The last window of insample size of all timeseries.
        This function does not support batching and does not reshuffle timeseries.

        :return: Last insample window of all timeseries. Shape "timeseries, insample size"
        """
        insample = np.zeros((len(self.timeseries), self.insample_size))
        insample_mask = np.zeros((len(self.timeseries), self.insample_size))
        for i, ts in enumerate(self.timeseries):
            ts_last_window = ts[-self.insample_size:]
            insample[i, -len(ts):] = ts_last_window
            insample_mask[i, -len(ts):] = 1.0
        return insample, insample_mask

# %%
# group_train[0] -> 년간 시계열
train_x =TimeseriesSampler(group_train[0],10,3,1)
test_y =TimeseriesSampler(group_test[0],10,3,1)

# %%
# X의 인풋사이즈 설정
# data의 길이가 인풋사이즈보다 작을때 문제점있음
lookback = np.array([2,3,4,5,6,7])
horizon = M4Meta.horizons_map['Yearly']
inputsize = lookback[0]*horizon
inputsize
# Out:
# 12

# %%
X = np.array([train_x.timeseries[i][-inputsize:] for i in range(len(train_x.timeseries))])
y = np.array([test_y.timeseries[i] for i in range(len(test_y.timeseries))])

# %%
X.shape ,y.shape
# Out:
# ((23000, 12), (23000, 6))

# %%
from sklearn.preprocessing import MinMaxScaler
minmax = MinMaxScaler()
X_scale= minmax.fit_transform(X)
y_scale=minmax.fit_transform(y)

# %% [markdown]
# ## target data
#
# - 대한민국 전력데이터 : 13년부터 20년 전력수요량

# %%
num= [20,21,22,23]
df = [pd.read_csv('C:\\Users\\default.DESKTOP-2ISHQBS\\lab\\task1\\demand{}.csv'.format(num[i]), encoding='cp949') for i in range(len(num))]
train_set = pd.concat([df[0],df[1]],axis=0)
vaild_set = df[2]
test_set=df[3]

train_set.shape, vaild_set.shape,test_set.shape
# Out:
# ((3287, 25), (365, 25), (365, 25))

# %%
class sample:
    #####################################################################################
    ### 데이터프레임, 날짜 입력
    ### 
    def __init__(self,df,str):
        self.df = df
        self.date= df[str]
        self.date=pd.to_datetime(self.date)
    def monthly(self):    
    #####################################################################################
    ### 시간별 데이터 -> 월별 데이터로
    ### 인덱스 : 년/월, 변수 : y        
        self.train = pd.DataFrame({'date':self.date,'y':self.df.iloc[:,1:].sum(axis=1).values})
        self.train = self.train.groupby(self.train['date'].dt.to_period('M')).sum(numeric_only=True)
        #self.index= self.df.index
        #self.sample = pd.DataFrame(self.df.sum(axis=1))
        #self.sample.columns = ['y']
        return self.train

# %%
target_train =sample(train_set,'날짜')
target_vaild =sample(vaild_set,'날짜')
target_test =sample(test_set,'날짜')

# %%
class WINdow:
    def __init__(self,df,timestep):
        self.df = df
        self.timestep=timestep+1 # 예상한 timestep보다 1적기 때문에 +1
        
    def window(self):
        for i in range(1, self.timestep):
            df['shift_{}'.format(i)] = df.iloc[:,0].shift(i)
            df['shift_{}'.format(i)] = df.iloc[:,0].shift(i)
        window_df = df.dropna(axis=0) # 결측치 공간 제거
        self.window_df = window_df.iloc[:,::-1] # 좌우 반전
        
                
        self.feature= self.window_df.iloc[:,:-1].values
        self.y_label= self.window_df.iloc[:,-1].values
        
        return self. window_df

# %%
df = target_train.monthly()
df_val = target_vaild.monthly()
df_test = target_test.monthly()

# %%
target=WINdow(df,18)
target_X = target.window().iloc[:,:12]
target_y = target.window().iloc[:,12:-1]

# %%
target_X
# Out:
#            shift_18    shift_17    shift_16    shift_15    shift_14  \
# date
# 2014-07  48146417.0  41021035.0  43124632.0  40302921.0  39773910.0
# 2014-08  41021035.0  43124632.0  40302921.0  39773910.0  40138415.0
# 2014-09  43124632.0  40302921.0  39773910.0  40138415.0  44009912.0
# 2014-10  40302921.0  39773910.0  40138415.0  44009912.0  44736826.0
# 2014-11  39773910.0  40138415.0  44009912.0  44736826.0  38407957.0
# ...             ...         ...         ...         ...         ...
# 2021-08  45276997.0  44655247.0  40530244.0  39968136.0  42249774.0
# 2021-09  44655247.0  40530244.0  39968136.0  42249774.0  45563568.0
# 2021-10  40530244.0  39968136.0  42249774.0  45563568.0  49833200.0
# 2021-11  39968136.0  42249774.0  45563568.0  49833200.0  43429122.0
# 2021-12  42249774.0  45563568.0  49833200.0  43429122.0  42130747.0
#
#            shift_13    shift_12    shift_11    shift_10     shift_9  \
# date
# 2014-07  40138415.0  44009912.0  44736826.0  38407957.0  40849274.0
# 2014-08  44009912.0  44736826.0  38407957.0  40849274.0  42582416.0
# 2014-09  44736826.0  38407957.0  40849274.0  42582416.0  46959676.0
# 2014-10  38407957.0  40849274.0  42582416.0  46959676.0  46867424.0
# 2014-11  40849274.0  42582416.0  46959676.0  46867424.0  41779631.0
# ...             ...         ...         ...         ...         ...
# 2021-08  45563568.0  49833200.0  43429122.0  42130747.0  43901883.0
# 2021-09  49833200.0  43429122.0  42130747.0  43901883.0  50533085.0
# 2021-10  43429122.0  42130747.0  43901883.0  50533085.0  51993772.0
# 2021-11  42130747.0  43901883.0  50533085.0  51993772.0  43570927.0
# 2021-12  43901883.0  50533085.0  51993772.0  43570927.0  45452646.0
#
#             shift_8     shift_7
# date
# 2014-07  42582416.0  46959676.0
# 2014-08  46959676.0  46867424.0
# 2014-09  46867424.0  41779631.0
# 2014-10  41779631.0  44251754.0
# 2014-11  44251754.0  40391497.0
# ...             ...         ...
# 2021-08  50533085.0  51993772.0
# 2021-09  51993772.0  43570927.0
# 2021-10  43570927.0  45452646.0
# 2021-11  45452646.0  41781923.0
# 2021-12  41781923.0  42547971.0
#
# [90 rows x 12 columns]

# %%
target_scale_X = minmax.fit_transform(target_X)
target_scale_y = minmax.fit_transform(target_y)

# %%
target_scale_X_train= target_scale_X[:-18,:] 
target_scale_y_train= target_scale_y[:-18,:] 

target_scale_X_test=target_scale_X[[-1],:] 
target_scale_y_test=target_scale_y[[-1],:]

# %% [markdown]
# ---

# %% [markdown]
# ## nbeats 모델 구현
# - **하이퍼파라미터는 최대한 논문과 유사하게 설정**
# - 앙상블은 아직 진행하지 않음
# - yearly에대한 단편적인 예측 모형
# - 단 데이터에 대한 scaling은 진행하였음

# %%
input_dim, output_dim =  1, 1
backcast=inputsize
forecast = M4Meta.horizons_map['Yearly']


K.clear_session()
model= NBeatsKeras( backcast_length=backcast, forecast_length=forecast, input_dim=input_dim,
                   output_dim=output_dim,stack_types=(NBeatsKeras.TREND_BLOCK,NBeatsKeras.TREND_BLOCK,NBeatsKeras.TREND_BLOCK,
                                                      NBeatsKeras.SEASONALITY_BLOCK,NBeatsKeras.SEASONALITY_BLOCK,NBeatsKeras.SEASONALITY_BLOCK)
                   ,nb_blocks_per_stack=4, thetas_dim=(2,2,2,4,4,4),
                   share_weights_in_stack=True, hidden_layer_units=128)
optimizer = Adam(learning_rate=0.001)
model.compile(loss='mse', optimizer=optimizer )
model.summary()
# Out:
# Model: "forecast"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_variable (InputLayer)    [(None, 12, 1)]      0           []
#
#  lambda (Lambda)                (None, 12)           0           ['input_variable[0][0]']
#
#  0/0/trend/d1 (Dense)           (None, 128)          1664        ['lambda[0][0]',
#                                                                   'subtract[0][0]',
#                                                                   'subtract_1[0][0]',
#                                                                   'subtract_2[0][0]']
#
#  0/0/trend/d2 (Dense)           (None, 128)          16512       ['0/0/trend/d1[0][0]',
#                                                                   '0/0/trend/d1[1][0]',
#                                                                   '0/0/trend/d1[2][0]',
#                                                                   '0/0/trend/d1[3][0]']
#
#  0/0/trend/d3 (Dense)           (None, 128)          16512       ['0/0/trend/d2[0][0]',
#                                                                   '0/0/trend/d2[1][0]',
#                                                                   '0/0/trend/d2[2][0]',
#                                                                   '0/0/trend/d2[3][0]']
#
#  0/0/trend/d4 (Dense)           (None, 128)          16512       ['0/0/trend/d3[0][0]',
#                                                                   '0/0/trend/d3[1][0]',
#                                                                   '0/0/trend/d3[2][0]',
#                                                                   '0/0/trend/d3[3][0]']
#
#  0/0/trend/theta_f_b (Dense)    (None, 2)            256         ['0/0/trend/d4[0][0]',
#                                                                   '0/0/trend/d4[0][0]',
#                                                                   '0/0/trend/d4[1][0]',
#                                                                   '0/0/trend/d4[1][0]',
#                                                                   '0/0/trend/d4[2][0]',
#                                                                   '0/0/trend/d4[2][0]',
#                                                                   '0/0/trend/d4[3][0]',
#                                                                   '0/0/trend/d4[3][0]']
#
#  lambda_1 (Lambda)              (None, 12)           0           ['0/0/trend/theta_f_b[1][0]']
#
#  subtract (Subtract)            (None, 12)           0           ['lambda[0][0]',
#                                                                   'lambda_1[0][0]']
#
#  lambda_3 (Lambda)              (None, 12)           0           ['0/0/trend/theta_f_b[3][0]']
#
#  subtract_1 (Subtract)          (None, 12)           0           ['subtract[0][0]',
#                                                                   'lambda_3[0][0]']
#
#  lambda_5 (Lambda)              (None, 12)           0           ['0/0/trend/theta_f_b[5][0]']
#
#  subtract_2 (Subtract)          (None, 12)           0           ['subtract_1[0][0]',
#                                                                   'lambda_5[0][0]']
#
#  lambda_7 (Lambda)              (None, 12)           0           ['0/0/trend/theta_f_b[7][0]']
#
#  subtract_3 (Subtract)          (None, 12)           0           ['subtract_2[0][0]',
#                                                                   'lambda_7[0][0]']
#
#  1/0/trend/d1 (Dense)           (None, 128)          1664        ['subtract_3[0][0]',
#                                                                   'subtract_4[0][0]',
#                                                                   'subtract_5[0][0]',
#                                                                   'subtract_6[0][0]']
#
#  1/0/trend/d2 (Dense)           (None, 128)          16512       ['1/0/trend/d1[0][0]',
#                                                                   '1/0/trend/d1[1][0]',
#                                                                   '1/0/trend/d1[2][0]',
#                                                                   '1/0/trend/d1[3][0]']
#
#  1/0/trend/d3 (Dense)           (None, 128)          16512       ['1/0/trend/d2[0][0]',
#                                                                   '1/0/trend/d2[1][0]',
#                                                                   '1/0/trend/d2[2][0]',
#                                                                   '1/0/trend/d2[3][0]']
#
#  1/0/trend/d4 (Dense)           (None, 128)          16512       ['1/0/trend/d3[0][0]',
#                                                                   '1/0/trend/d3[1][0]',
#                                                                   '1/0/trend/d3[2][0]',
#                                                                   '1/0/trend/d3[3][0]']
#
#  1/0/trend/theta_f_b (Dense)    (None, 2)            256         ['1/0/trend/d4[0][0]',
#                                                                   '1/0/trend/d4[0][0]',
#                                                                   '1/0/trend/d4[1][0]',
#                                                                   '1/0/trend/d4[1][0]',
#                                                                   '1/0/trend/d4[2][0]',
#                                                                   '1/0/trend/d4[2][0]',
#                                                                   '1/0/trend/d4[3][0]',
#                                                                   '1/0/trend/d4[3][0]']
#
#  lambda_9 (Lambda)              (None, 12)           0           ['1/0/trend/theta_f_b[1][0]']
#
#  subtract_4 (Subtract)          (None, 12)           0           ['subtract_3[0][0]',
#                                                                   'lambda_9[0][0]']
#
#  lambda_11 (Lambda)             (None, 12)           0           ['1/0/trend/theta_f_b[3][0]']
#
#  subtract_5 (Subtract)          (None, 12)           0           ['subtract_4[0][0]',
#                                                                   'lambda_11[0][0]']
#
#  lambda_13 (Lambda)             (None, 12)           0           ['1/0/trend/theta_f_b[5][0]']
#
#  subtract_6 (Subtract)          (None, 12)           0           ['subtract_5[0][0]',
#                                                                   'lambda_13[0][0]']
#
#  lambda_15 (Lambda)             (None, 12)           0           ['1/0/trend/theta_f_b[7][0]']
#
#  subtract_7 (Subtract)          (None, 12)           0           ['subtract_6[0][0]',
#                                                                   'lambda_15[0][0]']
#
#  2/0/trend/d1 (Dense)           (None, 128)          1664        ['subtract_7[0][0]',
#                                                                   'subtract_8[0][0]',
#                                                                   'subtract_9[0][0]',
#                                                                   'subtract_10[0][0]']
#
#  2/0/trend/d2 (Dense)           (None, 128)          16512       ['2/0/trend/d1[0][0]',
#                                                                   '2/0/trend/d1[1][0]',
#                                                                   '2/0/trend/d1[2][0]',
#                                                                   '2/0/trend/d1[3][0]']
#
#  2/0/trend/d3 (Dense)           (None, 128)          16512       ['2/0/trend/d2[0][0]',
#                                                                   '2/0/trend/d2[1][0]',
#                                                                   '2/0/trend/d2[2][0]',
#                                                                   '2/0/trend/d2[3][0]']
#
#  2/0/trend/d4 (Dense)           (None, 128)          16512       ['2/0/trend/d3[0][0]',
#                                                                   '2/0/trend/d3[1][0]',
#                                                                   '2/0/trend/d3[2][0]',
#                                                                   '2/0/trend/d3[3][0]']
#
#  2/0/trend/theta_f_b (Dense)    (None, 2)            256         ['2/0/trend/d4[0][0]',
#                                                                   '2/0/trend/d4[0][0]',
#                                                                   '2/0/trend/d4[1][0]',
#                                                                   '2/0/trend/d4[1][0]',
#                                                                   '2/0/trend/d4[2][0]',
#                                                                   '2/0/trend/d4[2][0]',
#                                                                   '2/0/trend/d4[3][0]',
#                                                                   '2/0/trend/d4[3][0]']
#
#  lambda_17 (Lambda)             (None, 12)           0           ['2/0/trend/theta_f_b[1][0]']
#
#  subtract_8 (Subtract)          (None, 12)           0           ['subtract_7[0][0]',
#                                                                   'lambda_17[0][0]']
#
#  lambda_19 (Lambda)             (None, 12)           0           ['2/0/trend/theta_f_b[3][0]']
#
#  subtract_9 (Subtract)          (None, 12)           0           ['subtract_8[0][0]',
#                                                                   'lambda_19[0][0]']
#
#  lambda_21 (Lambda)             (None, 12)           0           ['2/0/trend/theta_f_b[5][0]']
#
#  subtract_10 (Subtract)         (None, 12)           0           ['subtract_9[0][0]',
#                                                                   'lambda_21[0][0]']
#
#  lambda_23 (Lambda)             (None, 12)           0           ['2/0/trend/theta_f_b[7][0]']
#
#  subtract_11 (Subtract)         (None, 12)           0           ['subtract_10[0][0]',
#                                                                   'lambda_23[0][0]']
#
#  3/0/seasonality/d1 (Dense)     (None, 128)          1664        ['subtract_11[0][0]',
#                                                                   'subtract_12[0][0]',
#                                                                   'subtract_13[0][0]',
#                                                                   'subtract_14[0][0]']
#
#  3/0/seasonality/d2 (Dense)     (None, 128)          16512       ['3/0/seasonality/d1[0][0]',
#                                                                   '3/0/seasonality/d1[1][0]',
#                                                                   '3/0/seasonality/d1[2][0]',
#                                                                   '3/0/seasonality/d1[3][0]']
#
#  3/0/seasonality/d3 (Dense)     (None, 128)          16512       ['3/0/seasonality/d2[0][0]',
#                                                                   '3/0/seasonality/d2[1][0]',
#                                                                   '3/0/seasonality/d2[2][0]',
#                                                                   '3/0/seasonality/d2[3][0]']
#
#  3/0/seasonality/d4 (Dense)     (None, 128)          16512       ['3/0/seasonality/d3[0][0]',
#                                                                   '3/0/seasonality/d3[1][0]',
#                                                                   '3/0/seasonality/d3[2][0]',
#                                                                   '3/0/seasonality/d3[3][0]']
#
#  3/0/seasonality/theta_b (Dense  (None, 6)           768         ['3/0/seasonality/d4[0][0]',
#  )                                                                '3/0/seasonality/d4[1][0]',
#                                                                   '3/0/seasonality/d4[2][0]',
#                                                                   '3/0/seasonality/d4[3][0]']
#
#  lambda_25 (Lambda)             (None, 12)           0           ['3/0/seasonality/theta_b[0][0]']
#
#  subtract_12 (Subtract)         (None, 12)           0           ['subtract_11[0][0]',
#                                                                   'lambda_25[0][0]']
#
#  lambda_27 (Lambda)             (None, 12)           0           ['3/0/seasonality/theta_b[1][0]']
#
#  subtract_13 (Subtract)         (None, 12)           0           ['subtract_12[0][0]',
#                                                                   'lambda_27[0][0]']
#
#  lambda_29 (Lambda)             (None, 12)           0           ['3/0/seasonality/theta_b[2][0]']
#
#  subtract_14 (Subtract)         (None, 12)           0           ['subtract_13[0][0]',
#                                                                   'lambda_29[0][0]']
#
#  lambda_31 (Lambda)             (None, 12)           0           ['3/0/seasonality/theta_b[3][0]']
#
#  subtract_15 (Subtract)         (None, 12)           0           ['subtract_14[0][0]',
#                                                                   'lambda_31[0][0]']
#
#  4/0/seasonality/d1 (Dense)     (None, 128)          1664        ['subtract_15[0][0]',
#                                                                   'subtract_16[0][0]',
#                                                                   'subtract_17[0][0]',
#                                                                   'subtract_18[0][0]']
#
#  4/0/seasonality/d2 (Dense)     (None, 128)          16512       ['4/0/seasonality/d1[0][0]',
#                                                                   '4/0/seasonality/d1[1][0]',
#                                                                   '4/0/seasonality/d1[2][0]',
#                                                                   '4/0/seasonality/d1[3][0]']
#
#  4/0/seasonality/d3 (Dense)     (None, 128)          16512       ['4/0/seasonality/d2[0][0]',
#                                                                   '4/0/seasonality/d2[1][0]',
#                                                                   '4/0/seasonality/d2[2][0]',
#                                                                   '4/0/seasonality/d2[3][0]']
#
#  4/0/seasonality/d4 (Dense)     (None, 128)          16512       ['4/0/seasonality/d3[0][0]',
#                                                                   '4/0/seasonality/d3[1][0]',
#                                                                   '4/0/seasonality/d3[2][0]',
#                                                                   '4/0/seasonality/d3[3][0]']
#
#  4/0/seasonality/theta_b (Dense  (None, 6)           768         ['4/0/seasonality/d4[0][0]',
#  )                                                                '4/0/seasonality/d4[1][0]',
#                                                                   '4/0/seasonality/d4[2][0]',
#                                                                   '4/0/seasonality/d4[3][0]']
#
#  lambda_33 (Lambda)             (None, 12)           0           ['4/0/seasonality/theta_b[0][0]']
#
#  subtract_16 (Subtract)         (None, 12)           0           ['subtract_15[0][0]',
#                                                                   'lambda_33[0][0]']
#
#  lambda_35 (Lambda)             (None, 12)           0           ['4/0/seasonality/theta_b[1][0]']
#
#  subtract_17 (Subtract)         (None, 12)           0           ['subtract_16[0][0]',
#                                                                   'lambda_35[0][0]']
#
#  lambda_37 (Lambda)             (None, 12)           0           ['4/0/seasonality/theta_b[2][0]']
#
#  subtract_18 (Subtract)         (None, 12)           0           ['subtract_17[0][0]',
#                                                                   'lambda_37[0][0]']
#
#  lambda_39 (Lambda)             (None, 12)           0           ['4/0/seasonality/theta_b[3][0]']
#
#  subtract_19 (Subtract)         (None, 12)           0           ['subtract_18[0][0]',
#                                                                   'lambda_39[0][0]']
#
#  5/0/seasonality/d1 (Dense)     (None, 128)          1664        ['subtract_19[0][0]',
#                                                                   'subtract_20[0][0]',
#                                                                   'subtract_21[0][0]',
#                                                                   'subtract_22[0][0]']
#
#  5/0/seasonality/d2 (Dense)     (None, 128)          16512       ['5/0/seasonality/d1[0][0]',
#                                                                   '5/0/seasonality/d1[1][0]',
#                                                                   '5/0/seasonality/d1[2][0]',
#                                                                   '5/0/seasonality/d1[3][0]']
#
#  5/0/seasonality/d3 (Dense)     (None, 128)          16512       ['5/0/seasonality/d2[0][0]',
#                                                                   '5/0/seasonality/d2[1][0]',
#                                                                   '5/0/seasonality/d2[2][0]',
#                                                                   '5/0/seasonality/d2[3][0]']
#
#  5/0/seasonality/d4 (Dense)     (None, 128)          16512       ['5/0/seasonality/d3[0][0]',
#                                                                   '5/0/seasonality/d3[1][0]',
#                                                                   '5/0/seasonality/d3[2][0]',
#                                                                   '5/0/seasonality/d3[3][0]']
#
#  lambda_2 (Lambda)              (None, 6)            0           ['0/0/trend/theta_f_b[0][0]']
#
#  lambda_4 (Lambda)              (None, 6)            0           ['0/0/trend/theta_f_b[2][0]']
#
#  5/0/seasonality/theta_b (Dense  (None, 6)           768         ['5/0/seasonality/d4[0][0]',
#  )                                                                '5/0/seasonality/d4[1][0]',
#                                                                   '5/0/seasonality/d4[2][0]']
#
#  stack_0-TrendBlock_0_Dim_0 (La  (None, 6)           0           ['lambda_2[0][0]']
#  mbda)
#
#  stack_0-TrendBlock_1_Dim_0 (La  (None, 6)           0           ['lambda_4[0][0]']
#  mbda)
#
#  lambda_6 (Lambda)              (None, 6)            0           ['0/0/trend/theta_f_b[4][0]']
#
#  lambda_41 (Lambda)             (None, 12)           0           ['5/0/seasonality/theta_b[0][0]']
#
#  add (Add)                      (None, 6)            0           ['stack_0-TrendBlock_0_Dim_0[0][0
#                                                                  ]',
#                                                                   'stack_0-TrendBlock_1_Dim_0[0][0
#                                                                  ]']
#
#  stack_0-TrendBlock_2_Dim_0 (La  (None, 6)           0           ['lambda_6[0][0]']
#  mbda)
#
#  lambda_8 (Lambda)              (None, 6)            0           ['0/0/trend/theta_f_b[6][0]']
#
#  subtract_20 (Subtract)         (None, 12)           0           ['subtract_19[0][0]',
#                                                                   'lambda_41[0][0]']
#
#  add_1 (Add)                    (None, 6)            0           ['add[0][0]',
#                                                                   'stack_0-TrendBlock_2_Dim_0[0][0
#                                                                  ]']
#
#  stack_0-TrendBlock_3_Dim_0 (La  (None, 6)           0           ['lambda_8[0][0]']
#  mbda)
#
#  lambda_10 (Lambda)             (None, 6)            0           ['1/0/trend/theta_f_b[0][0]']
#
#  add_2 (Add)                    (None, 6)            0           ['add_1[0][0]',
#                                                                   'stack_0-TrendBlock_3_Dim_0[0][0
#                                                                  ]']
#
#  stack_1-TrendBlock_0_Dim_0 (La  (None, 6)           0           ['lambda_10[0][0]']
#  mbda)
#
#  lambda_12 (Lambda)             (None, 6)            0           ['1/0/trend/theta_f_b[2][0]']
#
#  add_3 (Add)                    (None, 6)            0           ['add_2[0][0]',
#                                                                   'stack_1-TrendBlock_0_Dim_0[0][0
#                                                                  ]']
#
#  stack_1-TrendBlock_1_Dim_0 (La  (None, 6)           0           ['lambda_12[0][0]']
#  mbda)
#
#  lambda_14 (Lambda)             (None, 6)            0           ['1/0/trend/theta_f_b[4][0]']
#
#  add_4 (Add)                    (None, 6)            0           ['add_3[0][0]',
#                                                                   'stack_1-TrendBlock_1_Dim_0[0][0
#                                                                  ]']
#
#  stack_1-TrendBlock_2_Dim_0 (La  (None, 6)           0           ['lambda_14[0][0]']
#  mbda)
#
#  lambda_16 (Lambda)             (None, 6)            0           ['1/0/trend/theta_f_b[6][0]']
#
#  add_5 (Add)                    (None, 6)            0           ['add_4[0][0]',
#                                                                   'stack_1-TrendBlock_2_Dim_0[0][0
#                                                                  ]']
#
#  stack_1-TrendBlock_3_Dim_0 (La  (None, 6)           0           ['lambda_16[0][0]']
#  mbda)
#
#  lambda_18 (Lambda)             (None, 6)            0           ['2/0/trend/theta_f_b[0][0]']
#
#  add_6 (Add)                    (None, 6)            0           ['add_5[0][0]',
#                                                                   'stack_1-TrendBlock_3_Dim_0[0][0
#                                                                  ]']
#
#  stack_2-TrendBlock_0_Dim_0 (La  (None, 6)           0           ['lambda_18[0][0]']
#  mbda)
#
#  lambda_20 (Lambda)             (None, 6)            0           ['2/0/trend/theta_f_b[2][0]']
#
#  lambda_43 (Lambda)             (None, 12)           0           ['5/0/seasonality/theta_b[1][0]']
#
#  add_7 (Add)                    (None, 6)            0           ['add_6[0][0]',
#                                                                   'stack_2-TrendBlock_0_Dim_0[0][0
#                                                                  ]']
#
#  stack_2-TrendBlock_1_Dim_0 (La  (None, 6)           0           ['lambda_20[0][0]']
#  mbda)
#
#  lambda_22 (Lambda)             (None, 6)            0           ['2/0/trend/theta_f_b[4][0]']
#
#  subtract_21 (Subtract)         (None, 12)           0           ['subtract_20[0][0]',
#                                                                   'lambda_43[0][0]']
#
#  add_8 (Add)                    (None, 6)            0           ['add_7[0][0]',
#                                                                   'stack_2-TrendBlock_1_Dim_0[0][0
#                                                                  ]']
#
#  stack_2-TrendBlock_2_Dim_0 (La  (None, 6)           0           ['lambda_22[0][0]']
#  mbda)
#
#  lambda_24 (Lambda)             (None, 6)            0           ['2/0/trend/theta_f_b[6][0]']
#
#  3/0/seasonality/theta_f (Dense  (None, 6)           768         ['3/0/seasonality/d4[0][0]',
#  )                                                                '3/0/seasonality/d4[1][0]',
#                                                                   '3/0/seasonality/d4[2][0]',
#                                                                   '3/0/seasonality/d4[3][0]']
#
#  add_9 (Add)                    (None, 6)            0           ['add_8[0][0]',
#                                                                   'stack_2-TrendBlock_2_Dim_0[0][0
#                                                                  ]']
#
#  stack_2-TrendBlock_3_Dim_0 (La  (None, 6)           0           ['lambda_24[0][0]']
#  mbda)
#
#  lambda_26 (Lambda)             (None, 6)            0           ['3/0/seasonality/theta_f[0][0]']
#
#  add_10 (Add)                   (None, 6)            0           ['add_9[0][0]',
#                                                                   'stack_2-TrendBlock_3_Dim_0[0][0
#                                                                  ]']
#
#  stack_3-SeasonalityBlock_0_Dim  (None, 6)           0           ['lambda_26[0][0]']
#  _0 (Lambda)
#
#  lambda_28 (Lambda)             (None, 6)            0           ['3/0/seasonality/theta_f[1][0]']
#
#  add_11 (Add)                   (None, 6)            0           ['add_10[0][0]',
#                                                                   'stack_3-SeasonalityBlock_0_Dim_
#                                                                  0[0][0]']
#
#  stack_3-SeasonalityBlock_1_Dim  (None, 6)           0           ['lambda_28[0][0]']
#  _0 (Lambda)
#
#  lambda_30 (Lambda)             (None, 6)            0           ['3/0/seasonality/theta_f[2][0]']
#
#  add_12 (Add)                   (None, 6)            0           ['add_11[0][0]',
#                                                                   'stack_3-SeasonalityBlock_1_Dim_
#                                                                  0[0][0]']
#
#  stack_3-SeasonalityBlock_2_Dim  (None, 6)           0           ['lambda_30[0][0]']
#  _0 (Lambda)
#
#  lambda_32 (Lambda)             (None, 6)            0           ['3/0/seasonality/theta_f[3][0]']
#
#  4/0/seasonality/theta_f (Dense  (None, 6)           768         ['4/0/seasonality/d4[0][0]',
#  )                                                                '4/0/seasonality/d4[1][0]',
#                                                                   '4/0/seasonality/d4[2][0]',
#                                                                   '4/0/seasonality/d4[3][0]']
#
#  add_13 (Add)                   (None, 6)            0           ['add_12[0][0]',
#                                                                   'stack_3-SeasonalityBlock_2_Dim_
#                                                                  0[0][0]']
#
#  stack_3-SeasonalityBlock_3_Dim  (None, 6)           0           ['lambda_32[0][0]']
#  _0 (Lambda)
#
#  lambda_34 (Lambda)             (None, 6)            0           ['4/0/seasonality/theta_f[0][0]']
#
#  lambda_45 (Lambda)             (None, 12)           0           ['5/0/seasonality/theta_b[2][0]']
#
#  add_14 (Add)                   (None, 6)            0           ['add_13[0][0]',
#                                                                   'stack_3-SeasonalityBlock_3_Dim_
#                                                                  0[0][0]']
#
#  stack_4-SeasonalityBlock_0_Dim  (None, 6)           0           ['lambda_34[0][0]']
#  _0 (Lambda)
#
#  lambda_36 (Lambda)             (None, 6)            0           ['4/0/seasonality/theta_f[1][0]']
#
#  subtract_22 (Subtract)         (None, 12)           0           ['subtract_21[0][0]',
#                                                                   'lambda_45[0][0]']
#
#  add_15 (Add)                   (None, 6)            0           ['add_14[0][0]',
#                                                                   'stack_4-SeasonalityBlock_0_Dim_
#                                                                  0[0][0]']
#
#  stack_4-SeasonalityBlock_1_Dim  (None, 6)           0           ['lambda_36[0][0]']
#  _0 (Lambda)
#
#  lambda_38 (Lambda)             (None, 6)            0           ['4/0/seasonality/theta_f[2][0]']
#
#  add_16 (Add)                   (None, 6)            0           ['add_15[0][0]',
#                                                                   'stack_4-SeasonalityBlock_1_Dim_
#                                                                  0[0][0]']
#
#  stack_4-SeasonalityBlock_2_Dim  (None, 6)           0           ['lambda_38[0][0]']
#  _0 (Lambda)
#
#  lambda_40 (Lambda)             (None, 6)            0           ['4/0/seasonality/theta_f[3][0]']
#
#  5/0/seasonality/theta_f (Dense  (None, 6)           768         ['5/0/seasonality/d4[0][0]',
#  )                                                                '5/0/seasonality/d4[1][0]',
#                                                                   '5/0/seasonality/d4[2][0]',
#                                                                   '5/0/seasonality/d4[3][0]']
#
#  add_17 (Add)                   (None, 6)            0           ['add_16[0][0]',
#                                                                   'stack_4-SeasonalityBlock_2_Dim_
#                                                                  0[0][0]']
#
#  stack_4-SeasonalityBlock_3_Dim  (None, 6)           0           ['lambda_40[0][0]']
#  _0 (Lambda)
#
#  lambda_42 (Lambda)             (None, 6)            0           ['5/0/seasonality/theta_f[0][0]']
#
#  add_18 (Add)                   (None, 6)            0           ['add_17[0][0]',
#                                                                   'stack_4-SeasonalityBlock_3_Dim_
#                                                                  0[0][0]']
#
#  stack_5-SeasonalityBlock_0_Dim  (None, 6)           0           ['lambda_42[0][0]']
#  _0 (Lambda)
#
#  lambda_44 (Lambda)             (None, 6)            0           ['5/0/seasonality/theta_f[1][0]']
#
#  add_19 (Add)                   (None, 6)            0           ['add_18[0][0]',
#                                                                   'stack_5-SeasonalityBlock_0_Dim_
#                                                                  0[0][0]']
#
#  stack_5-SeasonalityBlock_1_Dim  (None, 6)           0           ['lambda_44[0][0]']
#  _0 (Lambda)
#
#  lambda_46 (Lambda)             (None, 6)            0           ['5/0/seasonality/theta_f[2][0]']
#
#  add_20 (Add)                   (None, 6)            0           ['add_19[0][0]',
#                                                                   'stack_5-SeasonalityBlock_1_Dim_
#                                                                  0[0][0]']
#
#  stack_5-SeasonalityBlock_2_Dim  (None, 6)           0           ['lambda_46[0][0]']
#  _0 (Lambda)
#
#  lambda_48 (Lambda)             (None, 6)            0           ['5/0/seasonality/theta_f[3][0]']
#
#  add_21 (Add)                   (None, 6)            0           ['add_20[0][0]',
#                                                                   'stack_5-SeasonalityBlock_2_Dim_
#                                                                  0[0][0]']
#
#  stack_5-SeasonalityBlock_3_Dim  (None, 6)           0           ['lambda_48[0][0]']
#  _0 (Lambda)
#
#  add_22 (Add)                   (None, 6)            0           ['add_21[0][0]',
#                                                                   'stack_5-SeasonalityBlock_3_Dim_
#                                                                  0[0][0]']
#
#  reshape (Reshape)              (None, 6, 1)         0           ['add_22[0][0]']
#
# ==================================================================================================
# Total params: 312,576
# Trainable params: 312,576
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
early_stop = EarlyStopping(monitor='loss', patience=10, verbose=1, restore_best_weights=True)
#checkpoint = ModelCheckpoint('best_model.h9', monitor='loss', save_best_only=True, mode='max', verbose=1)
#model.save('best_model.h9')
history = model.fit(X_scale,y_scale,
                    epochs=100, batch_size=128,
                    callbacks=[early_stop])
# Out:
# Epoch 1/100
# 180/180 [==============================] - 26s 124ms/step - loss: 0.0070
# Epoch 2/100
# 180/180 [==============================] - 22s 123ms/step - loss: 1.7799e-04
# Epoch 3/100
# 180/180 [==============================] - 22s 123ms/step - loss: 1.5668e-04
# Epoch 4/100
# 180/180 [==============================] - 22s 123ms/step - loss: 1.6013e-04
# Epoch 5/100
# 180/180 [==============================] - 22s 123ms/step - loss: 1.5778e-04
# Epoch 6/100
# 180/180 [==============================] - 22s 123ms/step - loss: 1.5346e-04
# Epoch 7/100
# 180/180 [==============================] - 22s 123ms/step - loss: 1.5665e-04
# Epoch 8/100
# 180/180 [==============================] - 22s 123ms/step - loss: 1.4469e-04
# Epoch 9/100
# 180/180 [==============================] - 22s 123ms/step - loss: 1.4321e-04
# Epoch 10/100
# 180/180 [==============================] - 22s 123ms/step - loss: 1.4604e-04
# Epoch 11/100
# 180/180 [==============================] - 22s 123ms/step - loss: 1.5131e-04
# Epoch 12/100
# 180/180 [==============================] - 22s 123ms/step - loss: 1.4530e-04
# Epoch 13/100
# 180/180 [==============================] - 22s 124ms/step - loss: 1.4257e-04
# Epoch 14/100
# 180/180 [==============================] - 22s 123ms/step - loss: 1.4269e-04
# Epoch 15/100
# 180/180 [==============================] - 22s 123ms/step - loss: 1.4425e-04
# Epoch 16/100
# 180/180 [==============================] - 22s 123ms/step - loss: 1.4405e-04
# Epoch 17/100
# 180/180 [==============================] - 22s 123ms/step - loss: 1.4402e-04
# Epoch 18/100
# 180/180 [==============================] - 22s 123ms/step - loss: 1.3941e-04
# Epoch 19/100
# 180/180 [==============================] - 22s 123ms/step - loss: 1.3535e-04
# Epoch 20/100
# 180/180 [==============================] - 22s 123ms/step - loss: 1.4256e-04
# Epoch 21/100
# 180/180 [==============================] - 22s 124ms/step - loss: 1.3517e-04
# Epoch 22/100
# 180/180 [==============================] - 22s 123ms/step - loss: 1.3509e-04
# Epoch 23/100
# 180/180 [==============================] - 22s 123ms/step - loss: 1.3269e-04
# Epoch 24/100
# 180/180 [==============================] - 22s 124ms/step - loss: 1.3384e-04
# Epoch 25/100
# 180/180 [==============================] - 22s 124ms/step - loss: 1.3295e-04
# Epoch 26/100
# 180/180 [==============================] - 22s 124ms/step - loss: 1.2932e-04
# Epoch 27/100
# 180/180 [==============================] - 22s 124ms/step - loss: 1.3213e-04
# Epoch 28/100
# 180/180 [==============================] - 22s 124ms/step - loss: 1.3123e-04
# Epoch 29/100
# 180/180 [==============================] - 22s 124ms/step - loss: 1.3136e-04
# Epoch 30/100
# 180/180 [==============================] - 22s 125ms/step - loss: 1.3269e-04
# Epoch 31/100
# 180/180 [==============================] - 22s 125ms/step - loss: 1.2510e-04
# Epoch 32/100
# 180/180 [==============================] - 22s 124ms/step - loss: 1.2722e-04
# Epoch 33/100
# 180/180 [==============================] - 22s 124ms/step - loss: 1.3080e-04
# Epoch 34/100
# 180/180 [==============================] - 22s 124ms/step - loss: 1.3106e-04
# Epoch 35/100
# 180/180 [==============================] - 22s 124ms/step - loss: 1.5236e-04
# Epoch 36/100
# 180/180 [==============================] - 22s 124ms/step - loss: 1.3442e-04
# Epoch 37/100
# 180/180 [==============================] - 22s 124ms/step - loss: 1.3430e-04
# Epoch 38/100
# 180/180 [==============================] - 22s 124ms/step - loss: 1.3192e-04
# Epoch 39/100
# 180/180 [==============================] - 22s 124ms/step - loss: 1.2810e-04
# Epoch 40/100
# 180/180 [==============================] - 22s 124ms/step - loss: 1.3119e-04
# Epoch 41/100
# 180/180 [==============================] - ETA: 0s - loss: 1.2836e-04Restoring model weights from the end of the best epoch: 31.
# 180/180 [==============================] - 22s 124ms/step - loss: 1.2836e-04
# Epoch 41: early stopping

# %%
#plt.plot(pred_pretrain.flatten(), color='red')
#plt.plot(y_scale.flatten())
#plt.title('pred_y & y')
#plt.show()

# %%
plt.plot(history.history['loss'])
plt.title('train loss')
plt.show()

# %% [markdown]
# ---
# ## transfer learning

# %%
from keras.layers import *

# %%
X_scale = X_scale.reshape(X_scale.shape[0], X_scale.shape[1], 1)

# %%
backcast_length = 12
theta_dim1, theta_dim2 = 64,6
forecast_length = 6
unit=128

# %%
for layer in model.layers:
    layer.trainable = True

pretrained_layers = model.layers[:-1]
pretrained_model = Model(inputs=model.input, outputs=pretrained_layers[-1].output)


input1 = Input(shape=(backcast_length,1))
pretrained_output = pretrained_model(input1)
pretrained_output_reshaped = Reshape((forecast_length,-1))(pretrained_output)

# LSTM layer
lstm_output = LSTM(64, return_sequences=True)(pretrained_output_reshaped )
#concatenated_output = Concatenate()([pretrained_output_reshaped, lstm_output])

# Dense layer
dense_output = TimeDistributed(Dense(1))(lstm_output )

model_combined = Model(inputs=input1, outputs=dense_output)
model_combined.compile(loss='mean_squared_error', optimizer='adam')
model_combined.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 12, 1)]           0
#
#  model_2 (Functional)        (None, 6)                 312576
#
#  reshape_1 (Reshape)         (None, 6, 1)              0
#
#  lstm_1 (LSTM)               (None, 6, 64)             16896
#
#  time_distributed_1 (TimeDis  (None, 6, 1)             65
#  tributed)
#
# =================================================================
# Total params: 329,537
# Trainable params: 329,537
# Non-trainable params: 0
# _________________________________________________________________

# %%
early_stop = EarlyStopping(monitor='loss', patience=10, verbose=1, restore_best_weights=True)
history = model_combined.fit(target_scale_X_train,target_scale_y_train,
                             epochs=50, batch_size=2,
                             callbacks=[early_stop])
# Out:
# Epoch 1/50
# 36/36 [==============================] - 8s 38ms/step - loss: 0.0877
# Epoch 2/50
# 36/36 [==============================] - 1s 38ms/step - loss: 0.0474
# Epoch 3/50
# 36/36 [==============================] - 1s 38ms/step - loss: 0.0324
# Epoch 4/50
# 36/36 [==============================] - 1s 38ms/step - loss: 0.0265
# Epoch 5/50
# 36/36 [==============================] - 1s 38ms/step - loss: 0.0249
# Epoch 6/50
# 36/36 [==============================] - 1s 38ms/step - loss: 0.0256
# Epoch 7/50
# 36/36 [==============================] - 1s 38ms/step - loss: 0.0213
# Epoch 8/50
# 36/36 [==============================] - 1s 38ms/step - loss: 0.0178
# Epoch 9/50
# 36/36 [==============================] - 1s 38ms/step - loss: 0.0179
# Epoch 10/50
# 36/36 [==============================] - 1s 38ms/step - loss: 0.0147
# Epoch 11/50
# 36/36 [==============================] - 1s 38ms/step - loss: 0.0130
# Epoch 12/50
# 36/36 [==============================] - 1s 38ms/step - loss: 0.0118
# Epoch 13/50
# 36/36 [==============================] - 1s 38ms/step - loss: 0.0146
# Epoch 14/50
# 36/36 [==============================] - 1s 38ms/step - loss: 0.0145
# Epoch 15/50
# 36/36 [==============================] - 1s 38ms/step - loss: 0.0108
# Epoch 16/50
# 36/36 [==============================] - 1s 38ms/step - loss: 0.0127
# Epoch 17/50
# 36/36 [==============================] - 1s 38ms/step - loss: 0.0139
# Epoch 18/50
# 36/36 [==============================] - 1s 38ms/step - loss: 0.0112
# Epoch 19/50
# 36/36 [==============================] - 1s 38ms/step - loss: 0.0089
# Epoch 20/50
# 36/36 [==============================] - 1s 38ms/step - loss: 0.0100
# Epoch 21/50
# 36/36 [==============================] - 1s 38ms/step - loss: 0.0075
# Epoch 22/50
# 36/36 [==============================] - 1s 38ms/step - loss: 0.0057
# Epoch 23/50
# 36/36 [==============================] - 1s 38ms/step - loss: 0.0069
# Epoch 24/50
# 36/36 [==============================] - 1s 38ms/step - loss: 0.0070
# Epoch 25/50
# 36/36 [==============================] - 1s 38ms/step - loss: 0.0055
# Epoch 26/50
# 36/36 [==============================] - 1s 38ms/step - loss: 0.0048
# Epoch 27/50
# 36/36 [==============================] - 1s 38ms/step - loss: 0.0052
# Epoch 28/50
# 36/36 [==============================] - 1s 38ms/step - loss: 0.0099
# Epoch 29/50
# 36/36 [==============================] - 1s 38ms/step - loss: 0.0064
# Epoch 30/50
# 36/36 [==============================] - 1s 38ms/step - loss: 0.0052
# Epoch 31/50
# 36/36 [==============================] - 1s 38ms/step - loss: 0.0072
# Epoch 32/50
# 36/36 [==============================] - 1s 38ms/step - loss: 0.0082
# Epoch 33/50
# 36/36 [==============================] - 1s 38ms/step - loss: 0.0083
# Epoch 34/50
# 36/36 [==============================] - 1s 38ms/step - loss: 0.0059
# Epoch 35/50
# 36/36 [==============================] - 1s 38ms/step - loss: 0.0042
# Epoch 36/50
# 36/36 [==============================] - 1s 38ms/step - loss: 0.0038
# Epoch 37/50
# 36/36 [==============================] - 1s 38ms/step - loss: 0.0038
# Epoch 38/50
# 36/36 [==============================] - 1s 38ms/step - loss: 0.0036
# Epoch 39/50
# 36/36 [==============================] - 1s 38ms/step - loss: 0.0026
# Epoch 40/50
# 36/36 [==============================] - 1s 38ms/step - loss: 0.0025
# Epoch 41/50
# 36/36 [==============================] - 1s 38ms/step - loss: 0.0033
# Epoch 42/50
# 36/36 [==============================] - 1s 38ms/step - loss: 0.0030
# Epoch 43/50
# 36/36 [==============================] - 1s 38ms/step - loss: 0.0029
# Epoch 44/50
# 36/36 [==============================] - 1s 38ms/step - loss: 0.0033
# Epoch 45/50
# 36/36 [==============================] - 1s 38ms/step - loss: 0.0029
# Epoch 46/50
# 36/36 [==============================] - 1s 38ms/step - loss: 0.0023
# Epoch 47/50
# 36/36 [==============================] - 1s 38ms/step - loss: 0.0048
# Epoch 48/50
# 36/36 [==============================] - 1s 38ms/step - loss: 0.0039
# Epoch 49/50
# 36/36 [==============================] - 1s 38ms/step - loss: 0.0033
# Epoch 50/50
# 36/36 [==============================] - 1s 38ms/step - loss: 0.0039

# %%
plt.plot(history.history['loss'])
plt.title('train loss')
plt.show()

# %%
pred =model_combined.predict(target_scale_X_test)
# Out:
# 1/1 [==============================] - 1s 1s/step

# %% [markdown]
# ## 비교

# %%
target_scale_X_train.shape,target_scale_y_train.shape
# Out:
# ((72, 12), (72, 6))

# %%
K.clear_session()
modelnon0 = Sequential() # Sequeatial Model
modelnon0.add(LSTM(128, return_sequences=False,input_shape=(12, 1)))# (timestep, feature)
modelnon0.add(Dense(6)) # output = 1
modelnon0.compile(loss='mean_squared_error', optimizer='adam')

early_stop = EarlyStopping(monitor='loss', patience=10, verbose=0)
modelnon0.fit(target_scale_X_train,target_scale_y_train, epochs=50,
          batch_size=2, verbose=0, callbacks=[early_stop])

# %%
pred2=modelnon0.predict(target_scale_X_test)
# Out:
# 1/1 [==============================] - 0s 16ms/step

# %%
plt.plot(pred.flatten(),label=' nbeat_y') 
plt.plot(pred2.flatten(),label='lstm_y') 
plt.plot(target_scale_y_test.flatten(),label='obv_y')
plt.legend()
plt.show()

# %%
from sklearn.metrics import *
print('nbeats_mse',mean_squared_error(target_scale_y_test.flatten(),pred.flatten()))
print('lstm___mse',mean_squared_error(target_scale_y_test.flatten(),pred2.flatten()))
print('nbeats_mape',mean_absolute_percentage_error(target_scale_y_test.flatten(),pred.flatten()))
print('lstm___mape',mean_absolute_percentage_error(target_scale_y_test.flatten(),pred2.flatten()))
print('nbeats_msle',mean_squared_log_error(target_scale_y_test.flatten(),pred.flatten()))
print('lstm___msle',mean_squared_log_error(target_scale_y_test.flatten(),pred2.flatten()))
# Out:
# nbeats_mse 0.015181805327750474
# lstm___mse 0.012193469371196917
# nbeats_mape 0.1545225647118366
# lstm___mape 0.15547022765278853
# nbeats_msle 0.005584546101286912
# lstm___msle 0.0046713216590975855
